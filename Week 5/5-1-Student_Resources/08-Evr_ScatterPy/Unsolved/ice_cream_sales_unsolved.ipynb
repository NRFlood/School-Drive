# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(temp, sales)
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(block=None)>

# %%
# Set the upper and lower limits of our y axis

# %%
# Set the upper and lower limits of our x axis

# %%
# Create a title, x label, and y label for our chart

# %%
# Save an image of the chart and print to screen
# NOTE: If your plot shrinks after saving an image,
# update matplotlib to 2.2 or higher,
# or simply run the above cells again.
plt.scatter(temp, sales)
y_max = max(sales)
y_min = min(sales)
x_max = max(temp)
x_min = min(temp)
plt.xlim(x_min*.9, x_max*1.1)
plt.ylim(y_min*.9, y_max*1.1)
plt.title('Ice Cream Sales vs. Temp')
plt.xlabel('Temperature')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_29896/55802308.py in <module>
#      11 plt.ylim(y_min*.9, y_max*1.1)
#      12 plt.title('Ice Cream Sales vs. Temp')
# ---> 13 plt.xlabel('Temperature')
#      14 plt.show()
#
# TypeError: 'str' object is not callable
